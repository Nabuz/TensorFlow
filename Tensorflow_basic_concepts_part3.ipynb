# %% [markdown]
# # Batch Normalization:

# %% [markdown]
# #### We normalized layers' outputs, before to transform them into activation functions to avoid vanishing/exploding gradients problems during the traning phase<br><br> We also apply zero-centered to outputs. Then we apply scaling and shifting (same two values per layers).<br><br> At the end the model learn the optimale scale and mean of the outputs of each layer.<br> <br>With this techniques we avoid to normalized the input data <br><br> This kind of implementation takes more time for each layer that non implementation.

# %% [markdown]
# ## --- Construction phase: ---

# %%
from datetime import datetime
import numpy as np
from functools import partial
import tensorflow as tf

n_inputs = 28*28  #MNIST dataset.  . 
n_hidden1 = 300  #number of hidden neurons for layer 1 and 2 
n_hidden2 = 100
n_outputs = 10

now = datetime.utcnow().strftime("%Y%m%d%H%M%S") #now = time in a specific format (YYYYMMDDHHMMSS)
root_logdir = "tf_logs"
logdir = "{}/run-{}".format(root_logdir, now ) # The path where we save the data: tf_logs/run-YYYYMMDDHHMMSS

X = tf.placeholder(tf.float32, shape=(None,n_inputs), name = "X")

y = tf.placeholder(tf.int64, shape=(None), name="y")

training = tf.placeholder_with_default(False, shape = (), name = "training") # If we don't provide data to feed placeholder data are feed with "False"
# Out:
# C:\Users\nabu-pc\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ### Creating different layer:

# %%
my_batch_norm_layer = partial (tf.layers.batch_normalization, training = training, momentum = 0.9) # Training (True/False).
                                                            # It returns the output in training mode (normalized with stats of current patch)
                                                            # Or inference mode: normalized with moving statistics
                                                            # Momentum: for the moving average(During the training). The average is updated with: vnew<-vnew*0.9 + vold*(1-0.9)
                                                            # Good momentum 0.9, 0.99, 0.999. It increase with larger datasets and smaller mini-batches

with tf.name_scope("dnn_w_bn"):
    hidden1 = tf.layers.dense(X, n_hidden1, name = "hidden1")
    bn1 = my_batch_norm_layer(hidden1)
    bn1_act = tf.nn.elu(bn1)
    hidden2 = tf.layers.dense(bn1_act, n_hidden2, name = "hidden2")
    bn2 = my_batch_norm_layer(hidden2)
    bn2_act = tf.nn.elu(bn2)
    logits_before_bn = tf.layers.dense(bn2_act, n_outputs, name = "outputs")
    logits = my_batch_norm_layer(logits_before_bn)

# %% [markdown]
# ### Calculating the Cost function (Cross Entropy)/ Gradient Optimizer / Accuracy:

# %%
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits = logits)
    # It calculates the cross entropy based on the "logits" (the outpute before going through the softmax activation function)
    # It expects labels in the form of integers ranging from 0 to the number of classes minus 1 (0-9)
    #The output is 1D tensor with the cross entropy for each istance.
    loss = tf.reduce_mean(xentropy, name="loss") #it computes the mean cross entropy over all instances

learning_rate = 0.01

with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y,1) #For each instance it determines if the nn's prediction is correct by checking wheter 
                                          #or not the highest logit corresponds to the target class
                                          #It returns a 1d Tensor full of boolean values
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %% [markdown]
# ### Inizializing / save phase:

# %%
init = tf.global_variables_initializer() #We create a node to initialize all variables
saver = tf.train.Saver() # We will create a Saver to save our trained model parameters to disk

loss_summary = tf.summary.scalar('LOSS', loss) # Creates a node in the graph that will evaluate the MSE value and writes it to a TensoBoard-compatible binary log string called Summary
file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph()) # We create a filewriter that you use to write summaries to logfiles in the log directory
                                                                    # logdir = the patph of the logdir diretory. Second parameter = the graph we want to visualize

# %% [markdown]
# ## --- Execution phase: ---

# %% [markdown]
# #### Importing data:

# %%
from  tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/") # the minst object has different method. Some methods can extract 
                                                             # the training istance (50k instance), a validation set(5k instances)
                                                             # a test set(10k)
n_epochs = 40  # numbers of eboch we want to run
batch_size = 50
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# #### Finally we begin the execution phase!!!

# %%
extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS) # Batch_normalization creates few operations that must be evaluated
                                         # at each step during training in order tu update the moving averages (moving averages are 
                                         # needed in order to evaluate the training set's mean and standard deviation). These operations
                                         # are automatically added to UPDATE_OPS collection. So we get the list of operations in that collection
                                         # and run them at each training iteration.

n_batches = mnist.train.num_examples // batch_size

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for iteration in range(mnist.train.num_examples // batch_size):
            X_batch, y_batch = mnist.train.next_batch(batch_size)
            summary_str = loss_summary.eval(feed_dict={X: X_batch, y: y_batch})
            step = epoch * n_batches + iteration  
            file_writer.add_summary(summary_str, step)
            sess.run([training_op, extra_update_ops],feed_dict={training: True, X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict = {X: X_batch, y: y_batch})
        accuracy_val = accuracy.eval(feed_dict= {X: mnist.test.images, y: mnist.test.labels})
        print(epoch,"Train accuracy",acc_train, "Test accuracy:" , accuracy_val)
        save_patch = saver.save(sess, "/tmp/my_model_final3.ckpt")
        file_writer.close()

# For running Tensorboard, in the Anaconda Prompt IN /Progetto Forex/Python (our working directory) -> tensorboard --logdir tf_logs
# Out:
# 0 Train accuracy 0.94 Test accuracy: 0.924
# 1 Train accuracy 0.96 Test accuracy: 0.9461
# 2 Train accuracy 0.96 Test accuracy: 0.9559
# 3 Train accuracy 1.0 Test accuracy: 0.9617
# 4 Train accuracy 0.96 Test accuracy: 0.9656
# 5 Train accuracy 1.0 Test accuracy: 0.9674
# 6 Train accuracy 0.98 Test accuracy: 0.9686
# 7 Train accuracy 1.0 Test accuracy: 0.9724
# 8 Train accuracy 1.0 Test accuracy: 0.9735
# 9 Train accuracy 1.0 Test accuracy: 0.9728
# 10 Train accuracy 0.98 Test accuracy: 0.9742
# 11 Train accuracy 1.0 Test accuracy: 0.9759
# 12 Train accuracy 1.0 Test accuracy: 0.9756
# 13 Train accuracy 1.0 Test accuracy: 0.976
# 14 Train accuracy 1.0 Test accuracy: 0.9776
# 15 Train accuracy 1.0 Test accuracy: 0.9765
# 16 Train accuracy 1.0 Test accuracy: 0.9785
# 17 Train accuracy 1.0 Test accuracy: 0.977
# 18 Train accuracy 1.0 Test accuracy: 0.9801
# 19 Train accuracy 1.0 Test accuracy: 0.98
# 20 Train accuracy 1.0 Test accuracy: 0.9788
# 21 Train accuracy 1.0 Test accuracy: 0.9795
# 22 Train accuracy 1.0 Test accuracy: 0.98
# 23 Train accuracy 1.0 Test accuracy: 0.9781
# 24 Train accuracy 1.0 Test accuracy: 0.9784
# 25 Train accuracy 1.0 Test accuracy: 0.9801
# 26 Train accuracy 1.0 Test accuracy: 0.9807
# 27 Train accuracy 1.0 Test accuracy: 0.9796
# 28 Train accuracy 1.0 Test accuracy: 0.9795
# 29 Train accuracy 1.0 Test accuracy: 0.9803
# 30 Train accuracy 1.0 Test accuracy: 0.9806
# 31 Train accuracy 1.0 Test accuracy: 0.9828
# 32 Train accuracy 1.0 Test accuracy: 0.9811
# 33 Train accuracy 1.0 Test accuracy: 0.9795
# 34 Train accuracy 1.0 Test accuracy: 0.9809
# 35 Train accuracy 1.0 Test accuracy: 0.9809
# 36 Train accuracy 1.0 Test accuracy: 0.9815
# 37 Train accuracy 1.0 Test accuracy: 0.9811
# 38 Train accuracy 1.0 Test accuracy: 0.9809
# 39 Train accuracy 1.0 Test accuracy: 0.9809

# %% [markdown]
# #### Printing the list of operations in the graph :

# %%
for op in tf.get_default_graph().get_operations():
    print(op.name)
# Out:
# X
# y
# training/input
# training
# hidden1/kernel/Initializer/random_uniform/shape
# hidden1/kernel/Initializer/random_uniform/min
# hidden1/kernel/Initializer/random_uniform/max
# hidden1/kernel/Initializer/random_uniform/RandomUniform
# hidden1/kernel/Initializer/random_uniform/sub
# hidden1/kernel/Initializer/random_uniform/mul
# hidden1/kernel/Initializer/random_uniform
# hidden1/kernel
# hidden1/kernel/Assign
# hidden1/kernel/read
# hidden1/bias/Initializer/zeros
# hidden1/bias
# hidden1/bias/Assign
# hidden1/bias/read
# dnn_w_bn/hidden1/MatMul
# dnn_w_bn/hidden1/BiasAdd
# batch_normalization/gamma/Initializer/ones
# batch_normalization/gamma
# batch_normalization/gamma/Assign
# batch_normalization/gamma/read
# batch_normalization/beta/Initializer/zeros
# batch_normalization/beta
# batch_normalization/beta/Assign
# batch_normalization/beta/read
# batch_normalization/moving_mean/Initializer/zeros
# batch_normalization/moving_mean
# batch_normalization/moving_mean/Assign
# batch_normalization/moving_mean/read
# batch_normalization/moving_variance/Initializer/ones
# batch_normalization/moving_variance
# batch_normalization/moving_variance/Assign
# batch_normalization/moving_variance/read
# dnn_w_bn/batch_normalization/moments/mean/reduction_indices
# dnn_w_bn/batch_normalization/moments/mean
# dnn_w_bn/batch_normalization/moments/StopGradient
# dnn_w_bn/batch_normalization/moments/SquaredDifference
# dnn_w_bn/batch_normalization/moments/variance/reduction_indices
# dnn_w_bn/batch_normalization/moments/variance
# dnn_w_bn/batch_normalization/moments/Squeeze
# dnn_w_bn/batch_normalization/moments/Squeeze_1
# dnn_w_bn/batch_normalization/cond/Switch
# dnn_w_bn/batch_normalization/cond/switch_t
# dnn_w_bn/batch_normalization/cond/switch_f
# dnn_w_bn/batch_normalization/cond/pred_id
# dnn_w_bn/batch_normalization/cond/Switch_1
# dnn_w_bn/batch_normalization/cond/Switch_2
# dnn_w_bn/batch_normalization/cond/Merge
# dnn_w_bn/batch_normalization/cond_1/Switch
# dnn_w_bn/batch_normalization/cond_1/switch_t
# dnn_w_bn/batch_normalization/cond_1/switch_f
# dnn_w_bn/batch_normalization/cond_1/pred_id
# dnn_w_bn/batch_normalization/cond_1/Switch_1
# dnn_w_bn/batch_normalization/cond_1/Switch_2
# dnn_w_bn/batch_normalization/cond_1/Merge
# dnn_w_bn/batch_normalization/cond_2/Switch
# dnn_w_bn/batch_normalization/cond_2/switch_t
# dnn_w_bn/batch_normalization/cond_2/switch_f
# dnn_w_bn/batch_normalization/cond_2/pred_id
# dnn_w_bn/batch_normalization/cond_2/AssignMovingAvg/decay
# dnn_w_bn/batch_normalization/cond_2/AssignMovingAvg/sub
# dnn_w_bn/batch_normalization/cond_2/AssignMovingAvg/sub/Switch
# dnn_w_bn/batch_normalization/cond_2/AssignMovingAvg/sub/Switch_1
# dnn_w_bn/batch_normalization/cond_2/AssignMovingAvg/mul
# dnn_w_bn/batch_normalization/cond_2/AssignMovingAvg
# dnn_w_bn/batch_normalization/cond_2/AssignMovingAvg/Switch
# dnn_w_bn/batch_normalization/cond_2/Switch_1
# dnn_w_bn/batch_normalization/cond_2/Merge
# dnn_w_bn/batch_normalization/cond_3/Switch
# dnn_w_bn/batch_normalization/cond_3/switch_t
# dnn_w_bn/batch_normalization/cond_3/switch_f
# dnn_w_bn/batch_normalization/cond_3/pred_id
# dnn_w_bn/batch_normalization/cond_3/AssignMovingAvg/decay
# dnn_w_bn/batch_normalization/cond_3/AssignMovingAvg/sub
# dnn_w_bn/batch_normalization/cond_3/AssignMovingAvg/sub/Switch
# dnn_w_bn/batch_normalization/cond_3/AssignMovingAvg/sub/Switch_1
# dnn_w_bn/batch_normalization/cond_3/AssignMovingAvg/mul
# dnn_w_bn/batch_normalization/cond_3/AssignMovingAvg
# dnn_w_bn/batch_normalization/cond_3/AssignMovingAvg/Switch
# dnn_w_bn/batch_normalization/cond_3/Switch_1
# dnn_w_bn/batch_normalization/cond_3/Merge
# dnn_w_bn/batch_normalization/batchnorm/add/y
# dnn_w_bn/batch_normalization/batchnorm/add
# dnn_w_bn/batch_normalization/batchnorm/Rsqrt
# dnn_w_bn/batch_normalization/batchnorm/mul
# dnn_w_bn/batch_normalization/batchnorm/mul_1
# dnn_w_bn/batch_normalization/batchnorm/mul_2
# dnn_w_bn/batch_normalization/batchnorm/sub
# dnn_w_bn/batch_normalization/batchnorm/add_1
# dnn_w_bn/Elu
# hidden2/kernel/Initializer/random_uniform/shape
# hidden2/kernel/Initializer/random_uniform/min
# hidden2/kernel/Initializer/random_uniform/max
# hidden2/kernel/Initializer/random_uniform/RandomUniform
# hidden2/kernel/Initializer/random_uniform/sub
# hidden2/kernel/Initializer/random_uniform/mul
# hidden2/kernel/Initializer/random_uniform
# hidden2/kernel
# hidden2/kernel/Assign
# hidden2/kernel/read
# hidden2/bias/Initializer/zeros
# hidden2/bias
# hidden2/bias/Assign
# hidden2/bias/read
# dnn_w_bn/hidden2/MatMul
# dnn_w_bn/hidden2/BiasAdd
# batch_normalization_1/gamma/Initializer/ones
# batch_normalization_1/gamma
# batch_normalization_1/gamma/Assign
# batch_normalization_1/gamma/read
# batch_normalization_1/beta/Initializer/zeros
# batch_normalization_1/beta
# batch_normalization_1/beta/Assign
# batch_normalization_1/beta/read
# batch_normalization_1/moving_mean/Initializer/zeros
# batch_normalization_1/moving_mean
# batch_normalization_1/moving_mean/Assign
# batch_normalization_1/moving_mean/read
# batch_normalization_1/moving_variance/Initializer/ones
# batch_normalization_1/moving_variance
# batch_normalization_1/moving_variance/Assign
# batch_normalization_1/moving_variance/read
# dnn_w_bn/batch_normalization_1/moments/mean/reduction_indices
# dnn_w_bn/batch_normalization_1/moments/mean
# dnn_w_bn/batch_normalization_1/moments/StopGradient
# dnn_w_bn/batch_normalization_1/moments/SquaredDifference
# dnn_w_bn/batch_normalization_1/moments/variance/reduction_indices
# dnn_w_bn/batch_normalization_1/moments/variance
# dnn_w_bn/batch_normalization_1/moments/Squeeze
# dnn_w_bn/batch_normalization_1/moments/Squeeze_1
# dnn_w_bn/batch_normalization_1/cond/Switch
# dnn_w_bn/batch_normalization_1/cond/switch_t
# dnn_w_bn/batch_normalization_1/cond/switch_f
# dnn_w_bn/batch_normalization_1/cond/pred_id
# dnn_w_bn/batch_normalization_1/cond/Switch_1
# dnn_w_bn/batch_normalization_1/cond/Switch_2
# dnn_w_bn/batch_normalization_1/cond/Merge
# dnn_w_bn/batch_normalization_1/cond_1/Switch
# dnn_w_bn/batch_normalization_1/cond_1/switch_t
# dnn_w_bn/batch_normalization_1/cond_1/switch_f
# dnn_w_bn/batch_normalization_1/cond_1/pred_id
# dnn_w_bn/batch_normalization_1/cond_1/Switch_1
# dnn_w_bn/batch_normalization_1/cond_1/Switch_2
# dnn_w_bn/batch_normalization_1/cond_1/Merge
# dnn_w_bn/batch_normalization_1/cond_2/Switch
# dnn_w_bn/batch_normalization_1/cond_2/switch_t
# dnn_w_bn/batch_normalization_1/cond_2/switch_f
# dnn_w_bn/batch_normalization_1/cond_2/pred_id
# dnn_w_bn/batch_normalization_1/cond_2/AssignMovingAvg/decay
# dnn_w_bn/batch_normalization_1/cond_2/AssignMovingAvg/sub
# dnn_w_bn/batch_normalization_1/cond_2/AssignMovingAvg/sub/Switch
# dnn_w_bn/batch_normalization_1/cond_2/AssignMovingAvg/sub/Switch_1
# dnn_w_bn/batch_normalization_1/cond_2/AssignMovingAvg/mul
# dnn_w_bn/batch_normalization_1/cond_2/AssignMovingAvg
# dnn_w_bn/batch_normalization_1/cond_2/AssignMovingAvg/Switch
# dnn_w_bn/batch_normalization_1/cond_2/Switch_1
# dnn_w_bn/batch_normalization_1/cond_2/Merge
# dnn_w_bn/batch_normalization_1/cond_3/Switch
# dnn_w_bn/batch_normalization_1/cond_3/switch_t
# dnn_w_bn/batch_normalization_1/cond_3/switch_f
# dnn_w_bn/batch_normalization_1/cond_3/pred_id
# dnn_w_bn/batch_normalization_1/cond_3/AssignMovingAvg/decay
# dnn_w_bn/batch_normalization_1/cond_3/AssignMovingAvg/sub
# dnn_w_bn/batch_normalization_1/cond_3/AssignMovingAvg/sub/Switch
# dnn_w_bn/batch_normalization_1/cond_3/AssignMovingAvg/sub/Switch_1
# dnn_w_bn/batch_normalization_1/cond_3/AssignMovingAvg/mul
# dnn_w_bn/batch_normalization_1/cond_3/AssignMovingAvg
# dnn_w_bn/batch_normalization_1/cond_3/AssignMovingAvg/Switch
# dnn_w_bn/batch_normalization_1/cond_3/Switch_1
# dnn_w_bn/batch_normalization_1/cond_3/Merge
# dnn_w_bn/batch_normalization_1/batchnorm/add/y
# dnn_w_bn/batch_normalization_1/batchnorm/add
# dnn_w_bn/batch_normalization_1/batchnorm/Rsqrt
# dnn_w_bn/batch_normalization_1/batchnorm/mul
# dnn_w_bn/batch_normalization_1/batchnorm/mul_1
# dnn_w_bn/batch_normalization_1/batchnorm/mul_2
# dnn_w_bn/batch_normalization_1/batchnorm/sub
# dnn_w_bn/batch_normalization_1/batchnorm/add_1
# dnn_w_bn/Elu_1
# outputs/kernel/Initializer/random_uniform/shape
# outputs/kernel/Initializer/random_uniform/min
# outputs/kernel/Initializer/random_uniform/max
# outputs/kernel/Initializer/random_uniform/RandomUniform
# outputs/kernel/Initializer/random_uniform/sub
# outputs/kernel/Initializer/random_uniform/mul
# outputs/kernel/Initializer/random_uniform
# outputs/kernel
# outputs/kernel/Assign
# outputs/kernel/read
# outputs/bias/Initializer/zeros
# outputs/bias
# outputs/bias/Assign
# outputs/bias/read
# dnn_w_bn/outputs/MatMul
# dnn_w_bn/outputs/BiasAdd
# batch_normalization_2/gamma/Initializer/ones
# batch_normalization_2/gamma
# batch_normalization_2/gamma/Assign
# batch_normalization_2/gamma/read
# batch_normalization_2/beta/Initializer/zeros
# batch_normalization_2/beta
# batch_normalization_2/beta/Assign
# batch_normalization_2/beta/read
# batch_normalization_2/moving_mean/Initializer/zeros
# batch_normalization_2/moving_mean
# batch_normalization_2/moving_mean/Assign
# batch_normalization_2/moving_mean/read
# batch_normalization_2/moving_variance/Initializer/ones
# batch_normalization_2/moving_variance
# batch_normalization_2/moving_variance/Assign
# batch_normalization_2/moving_variance/read
# dnn_w_bn/batch_normalization_2/batchnorm/add/y
# dnn_w_bn/batch_normalization_2/batchnorm/add
# dnn_w_bn/batch_normalization_2/batchnorm/Rsqrt
# dnn_w_bn/batch_normalization_2/batchnorm/mul
# dnn_w_bn/batch_normalization_2/batchnorm/mul_1
# dnn_w_bn/batch_normalization_2/batchnorm/mul_2
# dnn_w_bn/batch_normalization_2/batchnorm/sub
# dnn_w_bn/batch_normalization_2/batchnorm/add_1
# loss/SparseSoftmaxCrossEntropyWithLogits/Shape
# loss/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits
# loss/Const
# loss/loss
# train/gradients/Shape
# train/gradients/grad_ys_0
# train/gradients/Fill
# train/gradients/loss/loss_grad/Reshape/shape
# train/gradients/loss/loss_grad/Reshape
# train/gradients/loss/loss_grad/Shape
# train/gradients/loss/loss_grad/Tile
# train/gradients/loss/loss_grad/Shape_1
# train/gradients/loss/loss_grad/Shape_2
# train/gradients/loss/loss_grad/Const
# train/gradients/loss/loss_grad/Prod
# train/gradients/loss/loss_grad/Const_1
# train/gradients/loss/loss_grad/Prod_1
# train/gradients/loss/loss_grad/Maximum/y
# train/gradients/loss/loss_grad/Maximum
# train/gradients/loss/loss_grad/floordiv
# train/gradients/loss/loss_grad/Cast
# train/gradients/loss/loss_grad/truediv
# train/gradients/zeros_like
# train/gradients/loss/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/PreventGradient
# train/gradients/loss/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/ExpandDims/dim
# train/gradients/loss/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/ExpandDims
# train/gradients/loss/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/mul
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/add_1_grad/Shape
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/add_1_grad/Shape_1
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/add_1_grad/BroadcastGradientArgs
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/add_1_grad/Sum
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/add_1_grad/Reshape
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/add_1_grad/Sum_1
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/add_1_grad/Reshape_1
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/add_1_grad/tuple/group_deps
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/add_1_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/add_1_grad/tuple/control_dependency_1
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/mul_1_grad/Shape
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/mul_1_grad/Shape_1
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/mul_1_grad/BroadcastGradientArgs
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/mul_1_grad/Mul
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/mul_1_grad/Sum
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/mul_1_grad/Reshape
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/mul_1_grad/Mul_1
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/mul_1_grad/Sum_1
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/mul_1_grad/Reshape_1
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/mul_1_grad/tuple/group_deps
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/mul_1_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/mul_1_grad/tuple/control_dependency_1
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/sub_grad/Neg
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/sub_grad/tuple/group_deps
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/sub_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/sub_grad/tuple/control_dependency_1
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/mul_2_grad/Mul
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/mul_2_grad/Mul_1
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/mul_2_grad/tuple/group_deps
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/mul_2_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/mul_2_grad/tuple/control_dependency_1
# train/gradients/dnn_w_bn/batch_normalization_2/cond/Merge_grad/cond_grad
# train/gradients/dnn_w_bn/batch_normalization_2/cond/Merge_grad/tuple/group_deps
# train/gradients/dnn_w_bn/batch_normalization_2/cond/Merge_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/batch_normalization_2/cond/Merge_grad/tuple/control_dependency_1
# train/gradients/AddN
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/mul_grad/Mul
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/mul_grad/Mul_1
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/mul_grad/tuple/group_deps
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/mul_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/mul_grad/tuple/control_dependency_1
# train/gradients/Switch
# train/gradients/Shape_1
# train/gradients/zeros/Const
# train/gradients/zeros
# train/gradients/dnn_w_bn/batch_normalization_2/cond/Switch_1_grad/cond_grad
# train/gradients/dnn_w_bn/batch_normalization_2/batchnorm/Rsqrt_grad/RsqrtGrad
# train/gradients/dnn_w_bn/batch_normalization_2/moments/Squeeze_grad/Shape
# train/gradients/dnn_w_bn/batch_normalization_2/moments/Squeeze_grad/Reshape
# train/gradients/dnn_w_bn/batch_normalization_2/moments/mean_grad/floordiv
# train/gradients/dnn_w_bn/batch_normalization_2/moments/mean_grad/Reshape
# train/gradients/dnn_w_bn/batch_normalization_2/moments/mean_grad/Tile
# train/gradients/dnn_w_bn/batch_normalization_2/moments/mean_grad/Shape_2
# train/gradients/dnn_w_bn/batch_normalization_2/moments/mean_grad/Shape_3
# train/gradients/dnn_w_bn/batch_normalization_2/moments/mean_grad/Const
# train/gradients/dnn_w_bn/batch_normalization_2/moments/mean_grad/Prod
# train/gradients/dnn_w_bn/batch_normalization_2/moments/mean_grad/Const_1
# train/gradients/dnn_w_bn/batch_normalization_2/moments/mean_grad/Prod_1
# train/gradients/dnn_w_bn/batch_normalization_2/moments/mean_grad/Maximum_1/y
# train/gradients/dnn_w_bn/batch_normalization_2/moments/mean_grad/Maximum_1
# train/gradients/dnn_w_bn/batch_normalization_2/moments/mean_grad/floordiv_1
# train/gradients/dnn_w_bn/batch_normalization_2/moments/mean_grad/Cast
# train/gradients/dnn_w_bn/batch_normalization_2/moments/mean_grad/truediv
# train/gradients/AddN_1
# train/gradients/dnn_w_bn/outputs/BiasAdd_grad/BiasAddGrad
# train/gradients/dnn_w_bn/outputs/BiasAdd_grad/tuple/group_deps
# train/gradients/dnn_w_bn/outputs/BiasAdd_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/outputs/BiasAdd_grad/tuple/control_dependency_1
# train/gradients/dnn_w_bn/outputs/MatMul_grad/MatMul
# train/gradients/dnn_w_bn/outputs/MatMul_grad/MatMul_1
# train/gradients/dnn_w_bn/outputs/MatMul_grad/tuple/group_deps
# train/gradients/dnn_w_bn/outputs/MatMul_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/outputs/MatMul_grad/tuple/control_dependency_1
# train/gradients/dnn_w_bn/Elu_1_grad/EluGrad
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/add_1_grad/Shape
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/add_1_grad/Shape_1
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/add_1_grad/BroadcastGradientArgs
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/add_1_grad/Sum
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/add_1_grad/Reshape
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/add_1_grad/Sum_1
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/add_1_grad/Reshape_1
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/add_1_grad/tuple/group_deps
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/add_1_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/add_1_grad/tuple/control_dependency_1
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/mul_1_grad/Shape
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/mul_1_grad/Shape_1
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/mul_1_grad/BroadcastGradientArgs
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/mul_1_grad/Mul
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/mul_1_grad/Sum
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/mul_1_grad/Reshape
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/mul_1_grad/Mul_1
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/mul_1_grad/Sum_1
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/mul_1_grad/Reshape_1
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/mul_1_grad/tuple/group_deps
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/mul_1_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/mul_1_grad/tuple/control_dependency_1
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/sub_grad/Neg
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/sub_grad/tuple/group_deps
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/sub_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/sub_grad/tuple/control_dependency_1
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/mul_2_grad/Mul
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/mul_2_grad/Mul_1
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/mul_2_grad/tuple/group_deps
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/mul_2_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/mul_2_grad/tuple/control_dependency_1
# train/gradients/dnn_w_bn/batch_normalization_1/cond/Merge_grad/cond_grad
# train/gradients/dnn_w_bn/batch_normalization_1/cond/Merge_grad/tuple/group_deps
# train/gradients/dnn_w_bn/batch_normalization_1/cond/Merge_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/batch_normalization_1/cond/Merge_grad/tuple/control_dependency_1
# train/gradients/AddN_2
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/mul_grad/Mul
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/mul_grad/Mul_1
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/mul_grad/tuple/group_deps
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/mul_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/mul_grad/tuple/control_dependency_1
# train/gradients/Switch_2
# train/gradients/Shape_3
# train/gradients/zeros_2/Const
# train/gradients/zeros_2
# train/gradients/dnn_w_bn/batch_normalization_1/cond/Switch_1_grad/cond_grad
# train/gradients/dnn_w_bn/batch_normalization_1/batchnorm/Rsqrt_grad/RsqrtGrad
# train/gradients/dnn_w_bn/batch_normalization_1/moments/Squeeze_grad/Shape
# train/gradients/dnn_w_bn/batch_normalization_1/moments/Squeeze_grad/Reshape
# train/gradients/dnn_w_bn/batch_normalization_1/moments/mean_grad/Maximum
# train/gradients/dnn_w_bn/batch_normalization_1/moments/mean_grad/floordiv
# train/gradients/dnn_w_bn/batch_normalization_1/moments/mean_grad/Reshape
# train/gradients/dnn_w_bn/batch_normalization_1/moments/mean_grad/Tile
# train/gradients/dnn_w_bn/batch_normalization_1/moments/mean_grad/Shape_2
# train/gradients/dnn_w_bn/batch_normalization_1/moments/mean_grad/Shape_3
# train/gradients/dnn_w_bn/batch_normalization_1/moments/mean_grad/Const
# train/gradients/dnn_w_bn/batch_normalization_1/moments/mean_grad/Prod
# train/gradients/dnn_w_bn/batch_normalization_1/moments/mean_grad/Const_1
# train/gradients/dnn_w_bn/batch_normalization_1/moments/mean_grad/Prod_1
# train/gradients/dnn_w_bn/batch_normalization_1/moments/mean_grad/Maximum_1/y
# train/gradients/dnn_w_bn/batch_normalization_1/moments/mean_grad/Maximum_1
# train/gradients/dnn_w_bn/batch_normalization_1/moments/mean_grad/floordiv_1
# train/gradients/dnn_w_bn/batch_normalization_1/moments/mean_grad/Cast
# train/gradients/dnn_w_bn/batch_normalization_1/moments/mean_grad/truediv
# train/gradients/AddN_3
# train/gradients/dnn_w_bn/hidden2/BiasAdd_grad/BiasAddGrad
# train/gradients/dnn_w_bn/hidden2/BiasAdd_grad/tuple/group_deps
# train/gradients/dnn_w_bn/hidden2/BiasAdd_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/hidden2/BiasAdd_grad/tuple/control_dependency_1
# train/gradients/dnn_w_bn/hidden2/MatMul_grad/MatMul
# train/gradients/dnn_w_bn/hidden2/MatMul_grad/MatMul_1
# train/gradients/dnn_w_bn/hidden2/MatMul_grad/tuple/group_deps
# train/gradients/dnn_w_bn/hidden2/MatMul_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/hidden2/MatMul_grad/tuple/control_dependency_1
# train/gradients/dnn_w_bn/Elu_grad/EluGrad
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/add_1_grad/Shape
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/add_1_grad/Shape_1
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/add_1_grad/BroadcastGradientArgs
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/add_1_grad/Sum
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/add_1_grad/Reshape
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/add_1_grad/Sum_1
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/add_1_grad/Reshape_1
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/add_1_grad/tuple/group_deps
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/add_1_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/add_1_grad/tuple/control_dependency_1
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/mul_1_grad/Shape
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/mul_1_grad/Shape_1
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/mul_1_grad/BroadcastGradientArgs
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/mul_1_grad/Mul
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/mul_1_grad/Sum
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/mul_1_grad/Reshape
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/mul_1_grad/Mul_1
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/mul_1_grad/Sum_1
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/mul_1_grad/Reshape_1
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/mul_1_grad/tuple/group_deps
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/mul_1_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/mul_1_grad/tuple/control_dependency_1
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/sub_grad/Neg
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/sub_grad/tuple/group_deps
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/sub_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/sub_grad/tuple/control_dependency_1
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/mul_2_grad/Mul
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/mul_2_grad/Mul_1
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/mul_2_grad/tuple/group_deps
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/mul_2_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/mul_2_grad/tuple/control_dependency_1
# train/gradients/dnn_w_bn/batch_normalization/cond/Merge_grad/cond_grad
# train/gradients/dnn_w_bn/batch_normalization/cond/Merge_grad/tuple/group_deps
# train/gradients/dnn_w_bn/batch_normalization/cond/Merge_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/batch_normalization/cond/Merge_grad/tuple/control_dependency_1
# train/gradients/AddN_4
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/mul_grad/Mul
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/mul_grad/Mul_1
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/mul_grad/tuple/group_deps
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/mul_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/mul_grad/tuple/control_dependency_1
# train/gradients/Switch_4
# train/gradients/Shape_5
# train/gradients/zeros_4/Const
# train/gradients/zeros_4
# train/gradients/dnn_w_bn/batch_normalization/cond/Switch_1_grad/cond_grad
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/Rsqrt_grad/RsqrtGrad
# train/gradients/dnn_w_bn/batch_normalization/moments/Squeeze_grad/Shape
# train/gradients/dnn_w_bn/batch_normalization/moments/Squeeze_grad/Reshape
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/add_grad/Shape
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/add_grad/Shape_1
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/add_grad/BroadcastGradientArgs
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/add_grad/Sum
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/add_grad/Reshape
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/add_grad/Sum_1
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/add_grad/Reshape_1
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/add_grad/tuple/group_deps
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/add_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/batch_normalization/batchnorm/add_grad/tuple/control_dependency_1
# train/gradients/dnn_w_bn/batch_normalization/cond_1/Merge_grad/cond_grad
# train/gradients/dnn_w_bn/batch_normalization/cond_1/Merge_grad/tuple/group_deps
# train/gradients/dnn_w_bn/batch_normalization/cond_1/Merge_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/batch_normalization/cond_1/Merge_grad/tuple/control_dependency_1
# train/gradients/Switch_5
# train/gradients/Shape_6
# train/gradients/zeros_5/Const
# train/gradients/zeros_5
# train/gradients/dnn_w_bn/batch_normalization/cond_1/Switch_1_grad/cond_grad
# train/gradients/dnn_w_bn/batch_normalization/moments/Squeeze_1_grad/Shape
# train/gradients/dnn_w_bn/batch_normalization/moments/Squeeze_1_grad/Reshape
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/Shape
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/Size
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/add
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/mod
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/Shape_1
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/range/start
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/range/delta
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/range
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/Fill/value
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/Fill
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/DynamicStitch
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/Maximum/y
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/Maximum
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/floordiv
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/Reshape
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/Tile
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/Shape_2
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/Shape_3
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/Const
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/Prod
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/Const_1
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/Prod_1
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/Maximum_1/y
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/Maximum_1
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/floordiv_1
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/Cast
# train/gradients/dnn_w_bn/batch_normalization/moments/variance_grad/truediv
# train/gradients/dnn_w_bn/batch_normalization/moments/SquaredDifference_grad/Shape
# train/gradients/dnn_w_bn/batch_normalization/moments/SquaredDifference_grad/Shape_1
# train/gradients/dnn_w_bn/batch_normalization/moments/SquaredDifference_grad/BroadcastGradientArgs
# train/gradients/dnn_w_bn/batch_normalization/moments/SquaredDifference_grad/scalar
# train/gradients/dnn_w_bn/batch_normalization/moments/SquaredDifference_grad/mul
# train/gradients/dnn_w_bn/batch_normalization/moments/SquaredDifference_grad/sub
# train/gradients/dnn_w_bn/batch_normalization/moments/SquaredDifference_grad/mul_1
# train/gradients/dnn_w_bn/batch_normalization/moments/SquaredDifference_grad/Sum
# train/gradients/dnn_w_bn/batch_normalization/moments/SquaredDifference_grad/Reshape
# train/gradients/dnn_w_bn/batch_normalization/moments/SquaredDifference_grad/Sum_1
# train/gradients/dnn_w_bn/batch_normalization/moments/SquaredDifference_grad/Reshape_1
# train/gradients/dnn_w_bn/batch_normalization/moments/SquaredDifference_grad/Neg
# train/gradients/dnn_w_bn/batch_normalization/moments/SquaredDifference_grad/tuple/group_deps
# train/gradients/dnn_w_bn/batch_normalization/moments/SquaredDifference_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/batch_normalization/moments/SquaredDifference_grad/tuple/control_dependency_1
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/Shape
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/Size
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/add
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/mod
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/Shape_1
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/range/start
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/range/delta
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/range
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/Fill/value
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/Fill
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/DynamicStitch
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/Maximum/y
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/Maximum
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/floordiv
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/Reshape
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/Tile
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/Shape_2
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/Shape_3
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/Const
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/Prod
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/Const_1
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/Prod_1
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/Maximum_1/y
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/Maximum_1
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/floordiv_1
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/Cast
# train/gradients/dnn_w_bn/batch_normalization/moments/mean_grad/truediv
# train/gradients/AddN_5
# train/gradients/dnn_w_bn/hidden1/BiasAdd_grad/BiasAddGrad
# train/gradients/dnn_w_bn/hidden1/BiasAdd_grad/tuple/group_deps
# train/gradients/dnn_w_bn/hidden1/BiasAdd_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/hidden1/BiasAdd_grad/tuple/control_dependency_1
# train/gradients/dnn_w_bn/hidden1/MatMul_grad/MatMul
# train/gradients/dnn_w_bn/hidden1/MatMul_grad/MatMul_1
# train/gradients/dnn_w_bn/hidden1/MatMul_grad/tuple/group_deps
# train/gradients/dnn_w_bn/hidden1/MatMul_grad/tuple/control_dependency
# train/gradients/dnn_w_bn/hidden1/MatMul_grad/tuple/control_dependency_1
# train/GradientDescent/learning_rate
# train/GradientDescent/update_hidden1/kernel/ApplyGradientDescent
# train/GradientDescent/update_hidden1/bias/ApplyGradientDescent
# train/GradientDescent/update_batch_normalization/gamma/ApplyGradientDescent
# train/GradientDescent/update_batch_normalization/beta/ApplyGradientDescent
# train/GradientDescent/update_hidden2/kernel/ApplyGradientDescent
# train/GradientDescent/update_hidden2/bias/ApplyGradientDescent
# train/GradientDescent/update_batch_normalization_1/gamma/ApplyGradientDescent
# train/GradientDescent/update_batch_normalization_1/beta/ApplyGradientDescent
# train/GradientDescent/update_outputs/kernel/ApplyGradientDescent
# train/GradientDescent/update_outputs/bias/ApplyGradientDescent
# train/GradientDescent/update_batch_normalization_2/gamma/ApplyGradientDescent
# train/GradientDescent/update_batch_normalization_2/beta/ApplyGradientDescent
# train/GradientDescent
# eval/in_top_k/InTopKV2/k
# eval/in_top_k/InTopKV2
# eval/Cast
# eval/Const
# eval/Mean
# init
# save/Const
# save/SaveV2/tensor_names
# save/SaveV2/shape_and_slices
# save/SaveV2
# save/control_dependency
# save/RestoreV2/tensor_names
# save/RestoreV2/shape_and_slices
# save/RestoreV2
# save/Assign
# save/Assign_1
# save/Assign_2
# save/Assign_3
# save/Assign_4
# save/Assign_5
# save/Assign_6
# save/Assign_7
# save/Assign_8
# save/Assign_9
# save/Assign_10
# save/Assign_11
# save/Assign_12
# save/Assign_13
# save/Assign_14
# save/Assign_15
# save/Assign_16
# save/Assign_17
# save/restore_all
# LOSS_1/tags
# LOSS_1
